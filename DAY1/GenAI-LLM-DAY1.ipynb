# %%
import sys
print(sys.version)
# Out:
# 3.13.5 | packaged by Anaconda, Inc. | (main, Jun 12 2025, 16:37:03) [MSC v.1929 64 bit (AMD64)]

# %%
import time
while(True):
    time.sleep(1)

# %%
print('hello')

# %%
mymodel = 'lamma'

# %%
print(mymodel)

# %%
nltk tool kit <== import nltk

import os   # os is a module
os.py <== existing python source file

import json # json also module

# %%
import os
os

# %%
import json
json

# %%
import matplotlib.pyplot

# matplotlib/
#            |--->pyplot.py
#                      |-->def plot():
#                      |-->def scatter():

# %%
matplotlib.pyplot.plot([1,2,3],[10,15,5])

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3],[10,15,5])

# %%
# import <moduleName>
import os
os.getcwd() # <moduleName>.<member>

# %%
from os import getcwd  # from <moduleName> import <member>
getcwd() # <member>

# %%
from matplotlib.pyplot import plot
plot([1,2,3],[10,2,30])

# %%
# dir(os)

# %%
import math
#help(math)
help(math.sqrt)

# %%
math.sqrt?

# %%
math.sqrt??

# %%
import nltk

# %%
text = "i likes to read machine learning algorithm"

# %%
from nltk.tokenize import word_tokenize 
word_tokenize(text)

# %%
LookupError
>>> import nltk
>>> nltk.download('punkt_tab')

# %%
import nltk
nltk.download('punkt_tab')

# %%
from nltk.tokenize import word_tokenize 
word_tokenize(text)

# %%
corpus = '''hello welcome,to gen ai training
do activity ! to become nlp learner
all the gen ai llm models are built on 
top of nlp'''

# %%
print(word_tokenize(corpus))

# %%
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
print(sent_tokenize(corpus))

# %%
msg="hello arun,how are you doing? ok. i am doing nlp activities's code ab'c data1.data2.#!/bin"

# %%
word_tokenize(msg)

# %%
from nltk.tokenize import wordpunct_tokenize
wordpunct_tokenize(msg)

# %%
msg="i can't do this, can i? ab'c def'g hi:j"

# %%
TreebankTokenizer 
 |->class 
      |->handles apostrophes 
      |->split punctuation
      |->adds space aroun punctuation  

can't => "ca" "n't" 
don't => "do" + "n't"
         ---     --- //token -->[1231312]

# %%
from nltk.tokenize import wordpunct_tokenize
print(wordpunct_tokenize)

# %%
from nltk.tokenize import TreebankWordTokenizer
print(TreebankWordTokenizer)

# %%
nltk/
  |
  |--tokenize/
           |___treebank.py
                      |
                      |->class TreebankWordTokenizer:
                              def tokenize(self,...):
                                     ..

# %%
print(nltk.__file__)

# %%
from nltk.tokenize import TreebankWordTokenizer
obj = TreebankWordTokenizer()
obj.tokenize(msg)

# %%
text = "they'll test-drive the car tomorrow"

# %%
from nltk.tokenize import word_tokenize,WordPunctTokenizer,TreebankWordTokenizer

# %%
print(word_tokenize(text))

# %%
print(WordPunctTokenizer().tokenize(text))

# %%
print(TreebankWordTokenizer().tokenize(text))

# %%
# nlp term 
# Stemming - stem -  reduce the root word

from nltk.stem import PorterStemmer
obj_stem = PorterStemmer()
obj_stem.stem("learning")

# %%
obj_stem.stem("history")

# %%
obj_stem.stem("congratulations")

# %%
from nltk.stem import RegexpStemmer
reg_stem = RegexpStemmer("ing$|s$|e$") # user specific regx pattern
reg_stem.stem("eating")

# %%
reg_stem.stem("aasdfdsfdsafsding")

# %%
reg_stem.stem("apple")

# %%
reg_stem.stem("bash")

# %%
reg_stem.stem("history")

# %%
# Lemmatization - lemma 
# reducing root word - based on pos = v,av...
#

# %%
from nltk.stem import WordNetLemmatizer
lemmatize_obj = WordNetLemmatizer()
lemmatize_obj.lemmatize("eating")

# %%
lemmatize_obj.lemmatize("eating",pos='v')

# %%
lemmatize_obj.lemmatize("history",pos='v')

# %%
the hotel food is good => hotel food good =>[12321,12312,12312]

# %%
Stopwords - NLP Preprocessing 
---------
 do not carrying significant meaning //

Reduce Noise
Reduce Vocabulary size
        |->improve the processing efficiency

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')

# %%
stopwords.words('english')
stopwords.words('french')
stopwords.words('arabic')

# %%
Tokenization ->token - reduce this token -stemm ->lemma ->stopwords

# %%
Given_lists = ["words","eats","eatern","writing",
               "writes","programming","program",
               "history","finally","finalized"]

# import nltk module
#  |->PorterStemmer - root words 
#  |-> WordNetLemmatizer - pos=v

# %%
Given_lists = ["words","eats","eatern","writing",
               "writes","programming","program",
               "history","finally","finalized"]

steem_obj = PorterStemmer()
for var in Given_lists:
    print(f'{var}  -->{steem_obj.stem(var)}')

# %%
lemmatizer_obj = WordNetLemmatizer()
for var in Given_lists:
    print(f"{var} -->{lemmatizer_obj.lemmatize(var,pos='v')}")

# %%
msg="This is an example displaying off list of or collection of stop words filters"
print(msg)

# %%
word_tokenize(msg)

# %%
words = word_tokenize(msg)
for var in words:
    if var.lower() not in stopwords.words('english'):
        print(var)

# %%
filter_words = [var for var in words if var.lower() not in stopwords.words('english')]
filter_words

# %%
# Task
# -------
Corpus 
 |->use PorterStemmer() and WordNetLemmatizer()
 |->apply stopwords
 |->Filter remaining words

# %%
corpus = '''Dr.Sarabhai is considered as the Father of the Indian space program; 
He was a great institution builder and established or helped to establish a large number 
of institutions in diverse fields. 
He was instrumental in establishing the Physical Research Laboratory (PRL) in Ahmedabad : after 
returning from Cambridge to an independent India in 1947, he persuaded charitable trusts 
controlled by his family and friends to endow a research institution near home in Ahmedabad.
Thus, Vikram Sarabhai founded the Physical Research Laboratory (PRL) in Ahmedabad on November 11, 1947. He was only 28 at that time. Sarabhai was a creator and cultivator of institutions and PRL was the first step in that direction. Vikram Sarabhai served of PRL from 1966-1971.
He was also Chairman of the Atomic Energy Commission. 
He along with other Ahmedabad-based industrialists played a major role in the creation 
of the Indian Institute of Management, Ahmedabad'''

# %%
docs = sent_tokenize(corpus)
print(type(docs),len(docs))

# %%
for var in range(len(docs)):
    words = word_tokenize(docs[var])
    print(words)

# %%
for var in range(len(docs)):
    words = word_tokenize(docs[var])
    for word in words:
        if word.lower() not in stopwords.words('english'):
            print(word.lower())

# %%
for var in range(len(docs)):
    words = word_tokenize(docs[var])
    for word in words:
        if word.lower() not in set(stopwords.words('english')):
            print(word.lower())

# %%
L=['data1','data2','data3','data1','data2','data1','data2','data1','data3']
set(L)

# %%
list(set(L))

# %%
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords

stemmer_obj = PorterStemmer()
docs = nltk.sent_tokenize(corpus)

for var in range(len(docs)):
    words = nltk.word_tokenize(docs[var])
    words = [stemmer_obj.stem(word) for word in words if word not in set(stopwords.words('english'))]
    docs[var] = " ".join(words)

docs

# %%
## use lemmatization

# %%
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

lemmatizer = WordNetLemmatizer()
docs = nltk.sent_tokenize(corpus)

for var in range(len(docs)):
    words = nltk.word_tokenize(docs[var])
    words = [lemmatizer.lemmatize(word,pos='v') for word in words 
             if word not in set(stopwords.words('english'))]
    docs[var] = " ".join(words)

docs

# %%
####
n-grams
An n-gram is contiguous sequence of n items from a given corpus.

food good bad <== afte applying lemmatization and stop words

[ food good bad ]
n=3 <== no.unique words

OneHotEncoding - embedding
n=1
food  ----->    1  0  0  =>[1,0,0]
good   ---->    0  1  0  =>[0,1,0]
bad   ----->    0  0  1  =>[0,0,1]

n=2
food good   --> 1 0
---------
good bad    --> 0 1
---------

n=3
food good bad  -> 1
                  0

this is ..... next word could..

# %%
from nltk.util import ngrams

# %%
data = "likes read nlp applications"
word_tokenize(data)

# %%
tokens = word_tokenize(data)
ngrams(tokens,1) # unigram

# %%
>>> def f1():
...     return 10
...
>>> f1()
10
>>> def f1():
...     yield 10
...
>>> f1()
<generator object f1 at 0x000002CA42309A80>
>>> next(f1())
10
>>> for var in f1():
...     print(var)
...
10
>>> list(f1())
[10]
>>>

# %%
list(ngrams(tokens,1) )

# %%
list(ngrams(tokens,2) )

# %%
list(ngrams(tokens,3) )

# %%
list(ngrams(tokens,4) )

# %%
list(ngrams(tokens,5) )

# %%
import numpy as np
from sklearn.preprocessing import OneHotEncoder

data = ['food','good','bad']

data = np.array(data).reshape(-1,1) # 2D

encoder_obj = OneHotEncoder(sparse_output=False)
one_hot = encoder_obj.fit_transform(data)
print(encoder_obj.categories_)
print('')
print(one_hot)

# %%
data = ['he','widely','regrad','father','indian','space','program']

# %%
data = np.array(data).reshape(-1,1) # 2D

encoder_obj = OneHotEncoder(sparse_output=False)
one_hot = encoder_obj.fit_transform(data)
print(encoder_obj.categories_)
print('')
print(one_hot)

# %%
np.array([10,20,30]).dtype

# %%
np.array([10,20,30.0]).dtype

# %%
np.array([10,20,30.0,'data']).dtype

# %%
arr = np.array([[10,20,30,40,50,60]])
arr.ndim

# %%
print(arr)

# %%
arr.reshape(2,3)

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
docs = [ "i likes nlp and i likes python","python and nlp course"]

cv = CountVectorizer()
bow = cv.fit_transform(docs)
print(cv.get_feature_names_out())
print(bow.toarray())

# %%
## TF-IDF
1000 - word/pattern ->python is appears => 5
                    ->nlp is appears --> 10 
TF-IDF -- reduce frequently occuring words and increases the importance of unique words
              No.of occurrences of the word
           -----------------------------------
TF =            Total words in the document
                
IDF  =  log (   N / df )

TF-IDF = TF x IDF
------

doc1:   python is easy to learn
doc2:   python and ruby are programming languages
doc3:   i like learning c programming languages

word - python
TF(D1) =    1 / 5 
DF = appears in doc1 and doc2 -> 2
N = 3

IDF = log( 3/2) =  N 

TF - ID =  0.2 X N  => score
score - python

# %%
from gensim.models import Word2Vec
docs = [ ["the","cat","sat","on","the","mat"],
        ["the","dog","sat","on","the","log"]]

model = Word2Vec(docs,vector_size=50)
model.wv["cat"]
model.wv.most_similar("cat")

# %%
Transformer - Encoder + Decoder

Encoder - Take sequence of inputs -->embeddings 
Decorder - embedding...
1. TokenEmbedding
    => Convert Text ->Vector
   ["nlp","food"] -->[1000,0100,200,3300,..4505] size of vector is 15 
Vs

2. Embedding 
    |
   ["nlp","food"] -->[101,13,3,13,12,12,1233,4343,234234,23423...34232,...N] size of vector is 5GB

3. self-Attention 
    W1 -  
    W2 - 
    0.7 
    0.3
4. parallel processing
================================================

# %%
###########  End of the day1 #######################
